# %%
from sklearn.datasets import load_sample_image
from sklearn.feature_extraction import image
one_image = load_sample_image("china.jpg")
one_image.shape
# Out:
# /home/akshay/anaconda3/lib/python3.6/site-packages/sklearn/datasets/base.py:762: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   images = [imread(filename) for filename in filenames]
# /home/akshay/anaconda3/lib/python3.6/site-packages/sklearn/datasets/base.py:762: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   images = [imread(filename) for filename in filenames]
# (427, 640, 3)

# %%
# from matplotlib.pyplot import imshow
# image = one_image[:,:,1] # X[0].reshape(w,h).T #assuming X[0] is of shape (400,)
# image.shape
# imshow(image, cmap='gray')

print('Image shape: {}'.format(one_image.shape))
patches = image.extract_patches_2d(one_image, (50, 50))
print('Patches shape: {}'.format(patches.shape))
# Out:
# Image shape: (427, 640, 3)
# Patches shape: (223398, 50, 50, 3)

# %%
print(patches[1].shape)
# Out:
# (50, 50, 3)

# %%
print(patches[800])
# Out:
# [[[187 214 243]
#   [188 215 244]]
#
#  [[187 214 243]
#   [188 215 244]]]

# %%
from matplotlib.pyplot import imshow
image = patches[100][:,:,1] # X[0].reshape(w,h).T #assuming X[0] is of shape (400,)
image.shape
imshow(image, cmap='gray')

# %%
from matplotlib.pyplot import imshow
image = one_image[:,:,1] # X[0].reshape(w,h).T #assuming X[0] is of shape (400,)
image.shape
imshow(image, cmap='gray')
